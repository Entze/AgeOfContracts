# %%
from clingo.symbol import Number, String
from clingo.control import Control

# %%
def run(axioms):
    evASP = Control("0")
    evASP.add("base", [], axioms)

    evASP.ground([("base", [])])
    
    with evASP.solve(yield_=True) as handle:
        #print(handle)
        for m in handle: 
            print("Answer:\n{}\n".format(m))

# %%
run("""
time(0..5).

holds(F,T+1) :- 
    holds(F,T),
    not -holds(F, T+1),
    time(T).

-holds(F,T+1) :- 
    -holds(F,T),
    not holds(F,T),
    time(t).



""")
# Out:
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5)

# %%
run("""

time(0..5).
state(init;unmoeg_S;initG;unmoegG_S).

obs(F,T+1) :- 
    obs(F,T),
    not not obs(F, T+1),
    time(T).

obs(comp(1,init),0).
occ(destr_S,0).

obs(comp(ID,New),T+1) :-
    occ(Act,T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).

trans(init,unmoeg_S,unmoeg_S).


""")
# Out:
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,unmoeg_S),5) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) obs(comp(1,init),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,init),4) obs(comp(1,init),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,init),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,init),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,unmoeg_S),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,unmoeg_S),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) obs(comp(1,init),5) obs(comp(1,init),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) obs(comp(1,init),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) obs(comp(1,init),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) obs(comp(1,init),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,init),2) obs(comp(1,init),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) obs(comp(1,init),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,init),2) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,init),2) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) obs(comp(1,unmoeg_S),6) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(1,unmoeg_S),5) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) obs(comp(1,unmoeg_S),3) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)
#
# Answer:
# time(0) time(1) time(2) time(3) time(4) time(5) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) obs(comp(1,unmoeg_S),2) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(destr_S,0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)

# %%
run("""

time(0).
state(init;unmoeg_S;initG;unmoegG_S).

gegen(1,2).
gegen(2,1).

obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T),
    not not obs(comp(ID,OtherState), T+1),
    State != OtherState,
    state(State), state(OtherState),
    T = 0.

obs(comp(1,init),0).
obs(comp(2,init),0).

occ(act(1,destr_S),0).
# %occ(act(2,wait),0).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).

trans(init,unmoeg_S,unmoeg_S).

#show obs/2.
#show occ/2.

""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(2,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,init),1) occ(act(1,destr_S),0)

# %%
run("""

obs(F,T+1) :- 
    obs(F,T),
    not -obs(F, T+1),
    time(T).

-obs(F,T+1) :- 
    -obs(F,T),
    not obs(F,T+1),
    time(t).

time(0).
state(init;unmoeg_S;initG;unmoegG_S).

obs(comp(1,init),0).
occ(act(1,destr_S),0).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).

trans(init,unmoeg_S,unmoeg_S).

#show obs/2.
#show occ/2.


""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) occ(act(1,destr_S),0)

# %%
run("""

obs(F,T+1) :- 
    obs(F,T),
    not -obs(F, T+1),
    time(T).

-obs(F,T+1) :- 
    -obs(F,T),
    not obs(F,T+1),
    time(t).

time(0).
state(init;unmoeg_S;initG;unmoegG_S).

obs(comp(1,init),0).
occ(act(1,destr_S),0).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).

trans(init,unmoeg_S,unmoeg_S).

%#show obs/2.
%#show occ/2.


""")
# Out:
# Answer:
# time(0) obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,unmoeg_S),1) trans(init,unmoeg_S,unmoeg_S) deo_type(destr_S,unmoeg_S) occ(act(1,destr_S),0) state(init) state(unmoeg_S) state(initG) state(unmoegG_S)

# %%
run("""
state(init;unmoeg_S;initG;unmoegG_S).

fluent(inertial, comp(ID, State)) :- state(State), ID = 1..2.

time(0..1).

obs(comp(ID,State),I+1) :- 
    fluent(inertial,comp(ID,State)), 
    obs(comp(ID,State),I),
    not -obs(comp(ID,Other),I+1),
    # %time(I+1),
    I = 0..1.
    
-obs(comp(ID,State),I+1) :- 
    fluent(inertial,comp(ID,State)), 
    -obs(comp(ID,State),I), 
    not obs(comp(ID,Other),I+1), 
    # %time(I+1),
    I = 0..1,
    Other != State, state(Other).


obs(comp(1,init),0).
occ(act(1,destr_S),0).
occ(act(1,wait),1).

# %obs(comp(2,init),0).
# %occ(act(2,wait),0).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).
trans(init,unmoeg_S,unmoeg_S).

deadline(1,2).

obs(comp(ID,Old),T+1) :-
    deadline(ID,Dead),
    T < Dead,
    occ(act(ID,wait),T),
    obs(comp(ID,Old),T).



%#show fluent/2.
#show obs/2.
#show occ/2.

""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(1,unmoeg_S),1) obs(comp(1,init),1) obs(comp(1,init),2) obs(comp(1,unmoeg_S),2) occ(act(1,destr_S),0) occ(act(1,wait),1)

# %% [markdown]
# ## !! above doesn't work
#
# ## down under does !!

# %%
run("""

time(0..3).
id(1..2).
state(init;unmoeg_S;initG;unmoegG_S).


obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T), 
    time(T),
    not -obs(comp(ID,State),T+1).

-obs(comp(ID,Else),T) :- 
    obs(comp(ID,State),T), 
    State != Else,
    state(Else).


obs(comp(1,init),0).
occ(act(1,destr_S),2).
obs(comp(2,init),0).
occ(act(2,destr_S),0).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New).

deo_type(destr_S,unmoeg_S).
trans(init,unmoeg_S,unmoeg_S).

#show obs/2.
%#show occ/2.

""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(2,init),0) obs(comp(1,init),1) obs(comp(2,unmoeg_S),1) obs(comp(2,unmoeg_S),2) obs(comp(1,init),2) obs(comp(2,unmoeg_S),3) obs(comp(1,unmoeg_S),3) obs(comp(1,unmoeg_S),4) obs(comp(2,unmoeg_S),4)

# %%
run("""


time(0..3).
id(1..2).
state(init;unmoeg_S;gewaehr;initG;unmoegG_S;gewaehrG).
dual(init,initG).
dual(unmoeg_S,unmoegG_S).
dual(gewaehr,gewaehrG).

gegen(1,2).
gegen(2,1).

obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T), 
    time(T),
    not -obs(comp(ID,State),T+1).

-obs(comp(ID,Else),T) :- 
    obs(comp(ID,State),T), 
    State != Else,
    state(Else).

obs(comp(1,init),0).
obs(comp(2,init),0).
# %occ(act(2,destr_S),0).
occ(act(2,destr_S),1).
# %occ(act(2,destr_S),2).
occ(act(1,geben),2).
occ(act(1,akzep),2).

occ(act(ID, ueberg),T) :-
    occ(act(ID,geben),T),
    occ(act(ID,akzep),T).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New),
    not hasDualAndGegenLOcc(ID,New,T).

hasDualAndGegenLOcc(ID,NewState,T) :-
    obs(comp(ID,NewState),T),
    gegen(ID,Gegen),
    occ(act(Gegen,ueberg),T),
    dual(NewState,_).

obs(comp(ID,Dual),T+1) :-
    not occ(act(ID,_),T),
    obs(comp(ID,NowState),T),
    dual(NowState,Dual),
    hasDualAndGegenLOcc(ID,NowState,T).


obs(comp(ID,DualState),T+1) :-
    occ(act(ID,Act),T),
    occ(act(Gegen,ueberg),T),
    gegen(ID,Gegen),
    obs(comp(ID,NowState),T),
    deo_type(Act,Deo_Type),
    trans(NowState,Deo_Type,NewState),
    dual(NewState,DualState).
    # %hasDualAndGegenLOcc(ID,NewState,T),
    # %gegen(ID,Gegen),
    # %occ(act(Gegen,ueberg),T).

deo_type(destr_S,unmoeg_S).
deo_type(ueberg,ueberg).
trans(init,unmoeg_S,unmoeg_S).
trans(init,ueberg,gewaehr).

#show obs/2.
#show occ/2.

# %hap(X,T) :- obs(X,T), X = comp(2,State).
%#show hap/2.

#show hasDualAndGegenLOcc/3.

""")

# %% [markdown]
# ## down under:
# #### 2 components, different moments of untergang, but lieferung in der anderen component (vor/gleichzeitig)

# %%
run("""



time(0..3).
id(1..2).
state(init;unmoeg_S;gewaehr;initG;unmoegG_S;gewaehrG).
dual(init,initG).
dual(unmoeg_S,unmoegG_S).
dual(gewaehr,gewaehrG).

gegen(1,2).
gegen(2,1).

obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T), 
    time(T),
    not -obs(comp(ID,State),T+1).

-obs(comp(ID,Else),T) :- 
    obs(comp(ID,State),T), 
    State != Else,
    state(Else).

obs(comp(1,init),0).
obs(comp(2,init),0).
# %occ(act(2,destr_S),1).
occ(act(2,destr_S),2).
# %occ(act(2,destr_S),3).
occ(act(1,geben),2).
occ(act(1,akzep),2).

occ(act(ID, ueberg),T) :-
    occ(act(ID,geben),T),
    occ(act(ID,akzep),T).

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New),
    not dualAndGegenL(New,ID,T).
    
dualAndGegenL(New,ID,T) :-
    dual(New,_),
    gegen(ID,OtherComp),
    occ(act(OtherComp, ueberg),T).

obs(comp(ID,Dual),T+1) :-
    not occ(act(ID,_),T),
    obs(comp(ID,NowState),T),
    dual(NowState,Dual),
    dualAndGegenL(NowState,ID,T).

obs(comp(ID,DualState),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,NowState),T),
    deo_type(Act,Deo_Type),
    trans(NowState,Deo_Type,NewState),
    dualAndGegenL(NewState,ID,T),
    # %gegen(ID,Gegen),
    # %occ(act(Gegen,ueberg),T),
    dual(NewState,DualState).

deo_type(destr_S,unmoeg_S).
deo_type(ueberg,ueberg).
trans(init,unmoeg_S,unmoeg_S).
trans(init,ueberg,gewaehr).

trans(DualOri,Type,DualDest) :- 
    dual(Ori,DualOri),
    dual(Dest,DualDest),
    trans(Ori,Type,Dest).

#show obs/2.
#show occ/2.
%#show dualAndGegenL/3.
%#show dual/2.
%#show trans/3.
%#show gegen/2.
%#show occ/2.




# %hap(X,T) :- obs(X,T), X = comp(2,State).
%#show hap/2.


""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(2,init),0) obs(comp(2,init),1) obs(comp(1,init),1) obs(comp(1,init),2) obs(comp(2,init),2) obs(comp(1,gewaehr),3) obs(comp(2,unmoegG_S),3) obs(comp(2,unmoegG_S),4) obs(comp(1,gewaehr),4) occ(act(2,destr_S),2) occ(act(1,geben),2) occ(act(1,akzep),2) occ(act(1,ueberg),2)

# %%
run("""


time(0..3).

%%%%% Graph

state(init;unmoeg_S;gewaehr;verzug_S;initG;unmoegG_S;gewaehrG;verzugG_S).
dual(init,initG).
dual(unmoeg_S,unmoegG_S).
dual(gewaehr,gewaehrG).
dual(verzug_S,verzugG_S).

trans(init,unmoeg_S,unmoeg_S).
trans(init,ueberg,gewaehr).
trans(init,verzug_S,verzug_S).

trans(DualOri,Type,DualDest) :- 
    dual(Ori,DualOri),
    dual(Dest,DualDest),
    trans(Ori,Type,Dest).
    
    
%%%%%   Action - MetaData

deo_type(destr_S,unmoeg_S).
deo_type(ueberg,ueberg).


%%%%%   Components

id(1..2).

gegen(1,2).
gegen(2,1).






%%%%%   Inertia


obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T), 
    time(T),
    not -obs(comp(ID,State),T+1).

-obs(comp(ID,Else),T) :- 
    obs(comp(ID,State),T), 
    State != Else,
    state(Else).


%%%%%     Übergabe

occ(act(ID, ueberg),T) :-
    occ(act(ID,geben),T),
    occ(act(ID,akzep),T).
    

%%%%%    State-Update

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New),
    not dualAndGegenL(New,ID,T).
    
dualAndGegenL(NewState, CompID,T) :-
    dual(NewState, _),
    gegen(CompID,OtherComp),
    occ(act(OtherComp, ueberg),T).

obs(comp(ID,Dual),T+1) :-
    not occ(act(ID,_),T),
    obs(comp(ID,NowState),T),
    dual(NowState,Dual),
    dualAndGegenL(NowState,ID,T).

obs(comp(ID,DualState),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,NowState),T),
    deo_type(Act,Deo_Type),
    trans(NowState,Deo_Type,NewState),
    dualAndGegenL(NewState,ID,T),
    # %gegen(ID,Gegen),
    # %occ(act(Gegen,ueberg),T),
    dual(NewState,DualState).





%%%%% Happening

obs(comp(1,init),0).
obs(comp(2,init),0).
# %occ(act(2,destr_S),1).
occ(act(2,destr_S),2).
# %occ(act(2,destr_S),3).
occ(act(1,geben),2).
occ(act(1,akzep),2).



%%%%%    Filter

#show obs/2.
%#show occ/2.
%#show dualAndGegenL/3.
%#show dual/2.
%#show trans/3.
%#show gegen/2.
%#show occ/2.




# %hap(X,T) :- obs(X,T), X = comp(2,State).
%#show hap/2.


""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(2,init),0) obs(comp(2,init),1) obs(comp(1,init),1) obs(comp(1,init),2) obs(comp(2,init),2) obs(comp(1,gewaehr),3) obs(comp(2,unmoegG_S),3) obs(comp(2,unmoegG_S),4) obs(comp(1,gewaehr),4)

# %%
run("""


time(0..3).

%%%%% Graph

state(init;unmoeg_S;gewaehr;verzug_S;initG;unmoegG_S;gewaehrG;verzugG_S).
dual(init,initG).
dual(unmoeg_S,unmoegG_S).
dual(gewaehr,gewaehrG).
dual(verzug_S,verzugG_S).

trans(init,unmoeg_S,unmoeg_S).
trans(init,ueberg,gewaehr).
trans(init,verzug_S,verzug_S).


%%%%%   Action - MetaData

deo_type(destr_S,unmoeg_S).
deo_type(ueberg,ueberg).


%%%%%   Components

id(1..2).

gegen(1,2).
gegen(2,1).


verzugsComp(1,3).
verzugsComp(2,4).





%%%%%   Inertia


obs(comp(ID,State),T+1) :- 
    obs(comp(ID,State),T), 
    time(T),
    not -obs(comp(ID,State),T+1).

-obs(comp(ID,Else),T) :- 
    obs(comp(ID,State),T), 
    State != Else,
    state(Else).


%%%%%     Übergabe

occ(act(ID, ueberg),T) :-
    occ(act(ID,geben),T),
    occ(act(ID,akzep),T),
    obs(comp(ID,Now),T),
    Now != abgeschl.
    

%%%%%    State-Update

obs(comp(ID,New),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,Old),T),
    deo_type(Act,Deo_Type),
    trans(Old,Deo_Type,New),
    not dualAndGegenL(New,ID,T).
    
dualAndGegenL(NewState, CompID,T) :-
    dual(NewState, _),
    gegen(CompID,OtherComp),
    occ(act(OtherComp, ueberg),T).

obs(comp(ID,Dual),T+1) :-
    not occ(act(ID,_),T),
    obs(comp(ID,NowState),T),
    dual(NowState,Dual),
    dualAndGegenL(NowState,ID,T).

obs(comp(ID,DualState),T+1) :-
    occ(act(ID,Act),T),
    obs(comp(ID,NowState),T),
    deo_type(Act,Deo_Type),
    trans(NowState,Deo_Type,NewState),
    dualAndGegenL(NewState,ID,T),
    # %gegen(ID,Gegen),
    # %occ(act(Gegen,ueberg),T),
    dual(NewState,DualState).










%%%%%    Filter

#show obs/2.
#show occ/2.
%#show dualAndGegenL/3.
%#show dual/2.
%#show trans/3.
%#show gegen/2.
%#show occ/2.




# %hap(X,T) :- obs(X,T), X = comp(2,State).
%#show hap/2.



%%%%% Happening

obs(comp(1,init),0).
# %obs(comp(2,init),0).
# %occ(act(2,destr_S),1).
# %occ(act(2,destr_S),2).
# %occ(act(2,destr_S),3).
# %deadline(1,1).
# %deadline(1,2).
deadline(1,3).
deadline(2,1).
occ(act(1,geben),2).
occ(act(1,akzep),2).

%%%%%    Verzug

2{obs(act(VerzugsID,initG), T+1); obs(comp(ID,abgeschlG),T+1)}2 :-
    obs(comp(ID,Now),T),
    Now != abgesch,
    verzugsComp(ID,VerzugsID),
    deadline(ID,T),
    dualAndGegenL(_, ID,Bevor),
    Bevor <=T,
    not occ(act(ID,ueberg),Before),
    time(Before),
    Before <= T.

2{obs(act(VerzugsID,init), T+1); obs(comp(ID,abgeschl),T+1)}2 :-
    obs(comp(ID,Now),T),
    Now != abgesch,
    verzugsComp(ID,VerzugsID),
    deadline(ID,T),
    not occ(act(ID,ueberg),Bevor),
    time(Bevor),
    Bevor <= T.

""")
# Out:
# Answer:
# obs(comp(1,init),0) obs(comp(1,init),1) obs(comp(1,init),2) obs(comp(1,gewaehr),3) obs(comp(1,abgeschl),4) obs(act(3,init),4) occ(act(1,geben),2) occ(act(1,akzep),2) occ(act(1,ueberg),2)

# %% [markdown]
# ## upside : warum entstht hier abgeschl ?
