# %%
import functools
from typing import Union, Callable

import clingo
from clingox.program import Program, ProgramObserver

# %%
static_rules = """

pos((X,Y)) :- X=1..3, Y=1..3, (X,Y) != (1,3), (X,Y) != (3,1).
adjacent((X1,Y1), (X2,Y2)) :- pos((X1,Y1)), pos((X2,Y2)), |X1 - X2| + |Y1 - Y2| = 1.

1 { observe(object(Type, Id), value(Property, Value), 0) : value(Property, Value) } 1 :- object(Type, Id).

value(at, Pos) :- pos(Pos).
action(move, Pos) :- pos(Pos).
action(wait, ()).

"""

# %%
effect_rules = """

observe(O, value(at, Pos2), T+1) :-
  time(T+1), time(T),
  occurs(O, action(move, Pos2), T),
  observe(O, value(at, Pos1), T),
  adjacent(Pos1, Pos2).

observe(O, value(at, Pos), T+1) :-
  time(T+1), time(T),
  occurs(O, action(wait, ()), T),
  observe(O, value(at, Pos), T).

observe(object(cell, Pos), value(collision, ()), T) :-
  observe(O1, value(at, Pos), T),
  observe(O2, value(at, Pos), T),
  O1 != O2.

observe(object(cell, Pos), value(collision, ()), T+1) :-
  O1 != O2,
  observe(O1, value(at, Pos), T),
  occurs(O2, action(move, Pos), T).

:- occurs(O, action(move, Pos2), T),                                 % Action
   time(T+1), time(T),
   observe(O, value(at, Pos1), T), adjacent(Pos1, Pos2),             % State
   observe(object(cell, Pos2), value(collision, ()), T+1).           % Precondition

"""

# %%
instance = """

object(robot, worker).
object(robot, charger).

init(object(robot, worker), value(at, (1,1))).
init(object(robot, charger), value(at, (2,2))).

goal(object(robot, worker), value(at, (3,3))).
goal(object(robot, charger), value(at, (2,2))).

"""

# %%
plan = """

time(0..k).

:- init(O, V), not observe(O, V, 0).
:- goal(O, V), not observe(O, V, k).

1 { occurs(object(ObjectType, Id), action(ActionType, Par), T) : action(ActionType, Par) } 1 :- object(ObjectType, Id), time(T), time(T+1).

"""

# %%
ctl = clingo.Control()
ctl.configuration.solve.models = 10
prg = Program()
obs = ProgramObserver(prg)
ctl.register_observer(obs)

# %%
ctl.add('base', [], static_rules)
ctl.add('base', [], effect_rules)
ctl.add('base', [], instance)
ctl.add('plan', ['k'], plan)
ctl.add('base', [], '#show observe/3. #show occurs/3.')

# %%
ctl.ground([("base", []), ("plan", [clingo.Number(4)])])

# %%
print("Facts:", len(prg.facts), "Rules:", len(prg.rules))
print(prg)
# Out:
# Facts: 0 Rules: 531
#  :- not observe(object(robot,charger),value(at,(2,2)),4).
#  :- not observe(object(robot,worker),value(at,(3,3)),4).
#  :- not observe(object(robot,worker),value(at,(1,1)),0).
#  :- not observe(object(robot,charger),value(at,(2,2)),0).
#  :- __x13, not __x231.
#  :- __x14, not __x234.
#  :- __x15, not __x237.
#  :- __x16, not __x240.
#  :- __x17, not __x243.
#  :- __x18, not __x246.
#  :- __x19, not __x249.
#  :- __x20, not __x252.
#  :- __x42, not __x255.
#  :- __x43, not __x258.
#  :- observe(object(cell,(3,3)),value(collision,()),1), observe(object(robot,charger),value(at,(3,2)),0), occurs(object(robot,charger),action(move,(3,3)),0).
#  :- observe(object(cell,(3,3)),value(collision,()),1), observe(object(robot,charger),value(at,(2,3)),0), occurs(object(robot,charger),action(move,(3,3)),0).
#  :- observe(object(cell,(3,3)),value(collision,()),1), observe(object(robot,worker),value(at,(3,2)),0), occurs(object(robot,worker),action(move,(3,3)),0).
#  :- observe(object(cell,(3,3)),value(collision,()),1), observe(object(robot,worker),value(at,(2,3)),0), occurs(object(robot,worker),action(move,(3,3)),0).
#  :- observe(object(cell,(3,2)),value(collision,()),1), observe(object(robot,charger),value(at,(3,3)),0), occurs(object(robot,charger),action(move,(3,2)),0).
#  :- observe(object(cell,(3,2)),value(collision,()),1), observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(3,2)),0).
#  :- observe(object(cell,(3,2)),value(collision,()),1), observe(object(robot,worker),value(at,(3,3)),0), occurs(object(robot,worker),action(move,(3,2)),0).
#  :- observe(object(cell,(3,2)),value(collision,()),1), observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(3,2)),0).
#  :- observe(object(cell,(2,3)),value(collision,()),1), observe(object(robot,charger),value(at,(3,3)),0), occurs(object(robot,charger),action(move,(2,3)),0).
#  :- observe(object(cell,(2,3)),value(collision,()),1), observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(2,3)),0).
#  :- observe(object(cell,(2,3)),value(collision,()),1), observe(object(robot,worker),value(at,(3,3)),0), occurs(object(robot,worker),action(move,(2,3)),0).
#  :- observe(object(cell,(2,3)),value(collision,()),1), observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(2,3)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,charger),value(at,(3,2)),0), occurs(object(robot,charger),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,charger),value(at,(2,3)),0), occurs(object(robot,charger),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,charger),value(at,(2,1)),0), occurs(object(robot,charger),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,charger),value(at,(1,2)),0), occurs(object(robot,charger),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,worker),value(at,(3,2)),0), occurs(object(robot,worker),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,worker),value(at,(2,3)),0), occurs(object(robot,worker),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,worker),value(at,(2,1)),0), occurs(object(robot,worker),action(move,(2,2)),0).
#  :- observe(object(cell,(2,2)),value(collision,()),1), observe(object(robot,worker),value(at,(1,2)),0), occurs(object(robot,worker),action(move,(2,2)),0).
#  :- observe(object(cell,(2,1)),value(collision,()),1), observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(2,1)),0).
#  :- observe(object(cell,(2,1)),value(collision,()),1), observe(object(robot,charger),value(at,(1,1)),0), occurs(object(robot,charger),action(move,(2,1)),0).
#  :- observe(object(cell,(2,1)),value(collision,()),1), observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(2,1)),0).
#  :- observe(object(cell,(2,1)),value(collision,()),1), observe(object(robot,worker),value(at,(1,1)),0), occurs(object(robot,worker),action(move,(2,1)),0).
#  :- observe(object(cell,(1,2)),value(collision,()),1), observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(1,2)),0).
#  :- observe(object(cell,(1,2)),value(collision,()),1), observe(object(robot,charger),value(at,(1,1)),0), occurs(object(robot,charger),action(move,(1,2)),0).
#  :- observe(object(cell,(1,2)),value(collision,()),1), observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(1,2)),0).
#  :- observe(object(cell,(1,2)),value(collision,()),1), observe(object(robot,worker),value(at,(1,1)),0), occurs(object(robot,worker),action(move,(1,2)),0).
#  :- observe(object(cell,(1,1)),value(collision,()),1), observe(object(robot,charger),value(at,(2,1)),0), occurs(object(robot,charger),action(move,(1,1)),0).
#  :- observe(object(cell,(1,1)),value(collision,()),1), observe(object(robot,charger),value(at,(1,2)),0), occurs(object(robot,charger),action(move,(1,1)),0).
#  :- observe(object(cell,(1,1)),value(collision,()),1), observe(object(robot,worker),value(at,(2,1)),0), occurs(object(robot,worker),action(move,(1,1)),0).
#  :- observe(object(cell,(1,1)),value(collision,()),1), observe(object(robot,worker),value(at,(1,2)),0), occurs(object(robot,worker),action(move,(1,1)),0).
#  :- observe(object(cell,(1,1)),value(collision,()),2), observe(object(robot,charger),value(at,(2,1)),1), occurs(object(robot,charger),action(move,(1,1)),1).
#  :- observe(object(cell,(1,1)),value(collision,()),2), observe(object(robot,charger),value(at,(1,2)),1), occurs(object(robot,charger),action(move,(1,1)),1).
#  :- observe(object(cell,(1,1)),value(collision,()),2), observe(object(robot,worker),value(at,(2,1)),1), occurs(object(robot,worker),action(move,(1,1)),1).
#  :- observe(object(cell,(1,1)),value(collision,()),2), observe(object(robot,worker),value(at,(1,2)),1), occurs(object(robot,worker),action(move,(1,1)),1).
#  :- observe(object(cell,(1,2)),value(collision,()),2), observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(1,2)),1).
#  :- observe(object(cell,(1,2)),value(collision,()),2), observe(object(robot,charger),value(at,(1,1)),1), occurs(object(robot,charger),action(move,(1,2)),1).
#  :- observe(object(cell,(1,2)),value(collision,()),2), observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(1,2)),1).
#  :- observe(object(cell,(1,2)),value(collision,()),2), observe(object(robot,worker),value(at,(1,1)),1), occurs(object(robot,worker),action(move,(1,2)),1).
#  :- observe(object(cell,(2,1)),value(collision,()),2), observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(2,1)),1).
#  :- observe(object(cell,(2,1)),value(collision,()),2), observe(object(robot,charger),value(at,(1,1)),1), occurs(object(robot,charger),action(move,(2,1)),1).
#  :- observe(object(cell,(2,1)),value(collision,()),2), observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(2,1)),1).
#  :- observe(object(cell,(2,1)),value(collision,()),2), observe(object(robot,worker),value(at,(1,1)),1), occurs(object(robot,worker),action(move,(2,1)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,charger),value(at,(3,2)),1), occurs(object(robot,charger),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,charger),value(at,(2,3)),1), occurs(object(robot,charger),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,charger),value(at,(2,1)),1), occurs(object(robot,charger),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,charger),value(at,(1,2)),1), occurs(object(robot,charger),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,worker),value(at,(3,2)),1), occurs(object(robot,worker),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,worker),value(at,(2,3)),1), occurs(object(robot,worker),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,worker),value(at,(2,1)),1), occurs(object(robot,worker),action(move,(2,2)),1).
#  :- observe(object(cell,(2,2)),value(collision,()),2), observe(object(robot,worker),value(at,(1,2)),1), occurs(object(robot,worker),action(move,(2,2)),1).
#  :- observe(object(cell,(2,3)),value(collision,()),2), observe(object(robot,charger),value(at,(3,3)),1), occurs(object(robot,charger),action(move,(2,3)),1).
#  :- observe(object(cell,(2,3)),value(collision,()),2), observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(2,3)),1).
#  :- observe(object(cell,(2,3)),value(collision,()),2), observe(object(robot,worker),value(at,(3,3)),1), occurs(object(robot,worker),action(move,(2,3)),1).
#  :- observe(object(cell,(2,3)),value(collision,()),2), observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(2,3)),1).
#  :- observe(object(cell,(3,2)),value(collision,()),2), observe(object(robot,charger),value(at,(3,3)),1), occurs(object(robot,charger),action(move,(3,2)),1).
#  :- observe(object(cell,(3,2)),value(collision,()),2), observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(3,2)),1).
#  :- observe(object(cell,(3,2)),value(collision,()),2), observe(object(robot,worker),value(at,(3,3)),1), occurs(object(robot,worker),action(move,(3,2)),1).
#  :- observe(object(cell,(3,2)),value(collision,()),2), observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(3,2)),1).
#  :- observe(object(cell,(3,3)),value(collision,()),2), observe(object(robot,charger),value(at,(3,2)),1), occurs(object(robot,charger),action(move,(3,3)),1).
#  :- observe(object(cell,(3,3)),value(collision,()),2), observe(object(robot,charger),value(at,(2,3)),1), occurs(object(robot,charger),action(move,(3,3)),1).
#  :- observe(object(cell,(3,3)),value(collision,()),2), observe(object(robot,worker),value(at,(3,2)),1), occurs(object(robot,worker),action(move,(3,3)),1).
#  :- observe(object(cell,(3,3)),value(collision,()),2), observe(object(robot,worker),value(at,(2,3)),1), occurs(object(robot,worker),action(move,(3,3)),1).
#  :- observe(object(cell,(3,3)),value(collision,()),3), observe(object(robot,worker),value(at,(2,3)),2), occurs(object(robot,worker),action(move,(3,3)),2).
#  :- observe(object(cell,(3,3)),value(collision,()),3), observe(object(robot,worker),value(at,(3,2)),2), occurs(object(robot,worker),action(move,(3,3)),2).
#  :- observe(object(cell,(3,3)),value(collision,()),3), observe(object(robot,charger),value(at,(2,3)),2), occurs(object(robot,charger),action(move,(3,3)),2).
#  :- observe(object(cell,(3,3)),value(collision,()),3), observe(object(robot,charger),value(at,(3,2)),2), occurs(object(robot,charger),action(move,(3,3)),2).
#  :- observe(object(cell,(3,2)),value(collision,()),3), observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(3,2)),2).
#  :- observe(object(cell,(3,2)),value(collision,()),3), observe(object(robot,worker),value(at,(3,3)),2), occurs(object(robot,worker),action(move,(3,2)),2).
#  :- observe(object(cell,(3,2)),value(collision,()),3), observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(3,2)),2).
#  :- observe(object(cell,(3,2)),value(collision,()),3), observe(object(robot,charger),value(at,(3,3)),2), occurs(object(robot,charger),action(move,(3,2)),2).
#  :- observe(object(cell,(2,3)),value(collision,()),3), observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(2,3)),2).
#  :- observe(object(cell,(2,3)),value(collision,()),3), observe(object(robot,worker),value(at,(3,3)),2), occurs(object(robot,worker),action(move,(2,3)),2).
#  :- observe(object(cell,(2,3)),value(collision,()),3), observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(2,3)),2).
#  :- observe(object(cell,(2,3)),value(collision,()),3), observe(object(robot,charger),value(at,(3,3)),2), occurs(object(robot,charger),action(move,(2,3)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,worker),value(at,(1,2)),2), occurs(object(robot,worker),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,worker),value(at,(2,1)),2), occurs(object(robot,worker),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,worker),value(at,(2,3)),2), occurs(object(robot,worker),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,worker),value(at,(3,2)),2), occurs(object(robot,worker),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,charger),value(at,(1,2)),2), occurs(object(robot,charger),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,charger),value(at,(2,1)),2), occurs(object(robot,charger),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,charger),value(at,(2,3)),2), occurs(object(robot,charger),action(move,(2,2)),2).
#  :- observe(object(cell,(2,2)),value(collision,()),3), observe(object(robot,charger),value(at,(3,2)),2), occurs(object(robot,charger),action(move,(2,2)),2).
#  :- observe(object(cell,(2,1)),value(collision,()),3), observe(object(robot,worker),value(at,(1,1)),2), occurs(object(robot,worker),action(move,(2,1)),2).
#  :- observe(object(cell,(2,1)),value(collision,()),3), observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(2,1)),2).
#  :- observe(object(cell,(2,1)),value(collision,()),3), observe(object(robot,charger),value(at,(1,1)),2), occurs(object(robot,charger),action(move,(2,1)),2).
#  :- observe(object(cell,(2,1)),value(collision,()),3), observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(2,1)),2).
#  :- observe(object(cell,(1,2)),value(collision,()),3), observe(object(robot,worker),value(at,(1,1)),2), occurs(object(robot,worker),action(move,(1,2)),2).
#  :- observe(object(cell,(1,2)),value(collision,()),3), observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(1,2)),2).
#  :- observe(object(cell,(1,2)),value(collision,()),3), observe(object(robot,charger),value(at,(1,1)),2), occurs(object(robot,charger),action(move,(1,2)),2).
#  :- observe(object(cell,(1,2)),value(collision,()),3), observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(1,2)),2).
#  :- observe(object(cell,(1,1)),value(collision,()),3), observe(object(robot,worker),value(at,(1,2)),2), occurs(object(robot,worker),action(move,(1,1)),2).
#  :- observe(object(cell,(1,1)),value(collision,()),3), observe(object(robot,worker),value(at,(2,1)),2), occurs(object(robot,worker),action(move,(1,1)),2).
#  :- observe(object(cell,(1,1)),value(collision,()),3), observe(object(robot,charger),value(at,(1,2)),2), occurs(object(robot,charger),action(move,(1,1)),2).
#  :- observe(object(cell,(1,1)),value(collision,()),3), observe(object(robot,charger),value(at,(2,1)),2), occurs(object(robot,charger),action(move,(1,1)),2).
#  :- observe(object(cell,(1,1)),value(collision,()),4), observe(object(robot,charger),value(at,(2,1)),3), occurs(object(robot,charger),action(move,(1,1)),3).
#  :- observe(object(cell,(1,1)),value(collision,()),4), observe(object(robot,charger),value(at,(1,2)),3), occurs(object(robot,charger),action(move,(1,1)),3).
#  :- observe(object(cell,(1,1)),value(collision,()),4), observe(object(robot,worker),value(at,(2,1)),3), occurs(object(robot,worker),action(move,(1,1)),3).
#  :- observe(object(cell,(1,1)),value(collision,()),4), observe(object(robot,worker),value(at,(1,2)),3), occurs(object(robot,worker),action(move,(1,1)),3).
#  :- observe(object(cell,(1,2)),value(collision,()),4), observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(1,2)),3).
#  :- observe(object(cell,(1,2)),value(collision,()),4), observe(object(robot,charger),value(at,(1,1)),3), occurs(object(robot,charger),action(move,(1,2)),3).
#  :- observe(object(cell,(1,2)),value(collision,()),4), observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(1,2)),3).
#  :- observe(object(cell,(1,2)),value(collision,()),4), observe(object(robot,worker),value(at,(1,1)),3), occurs(object(robot,worker),action(move,(1,2)),3).
#  :- observe(object(cell,(2,1)),value(collision,()),4), observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(2,1)),3).
#  :- observe(object(cell,(2,1)),value(collision,()),4), observe(object(robot,charger),value(at,(1,1)),3), occurs(object(robot,charger),action(move,(2,1)),3).
#  :- observe(object(cell,(2,1)),value(collision,()),4), observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(2,1)),3).
#  :- observe(object(cell,(2,1)),value(collision,()),4), observe(object(robot,worker),value(at,(1,1)),3), occurs(object(robot,worker),action(move,(2,1)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,charger),value(at,(3,2)),3), occurs(object(robot,charger),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,charger),value(at,(2,3)),3), occurs(object(robot,charger),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,charger),value(at,(2,1)),3), occurs(object(robot,charger),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,charger),value(at,(1,2)),3), occurs(object(robot,charger),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,worker),value(at,(3,2)),3), occurs(object(robot,worker),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,worker),value(at,(2,3)),3), occurs(object(robot,worker),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,worker),value(at,(2,1)),3), occurs(object(robot,worker),action(move,(2,2)),3).
#  :- observe(object(cell,(2,2)),value(collision,()),4), observe(object(robot,worker),value(at,(1,2)),3), occurs(object(robot,worker),action(move,(2,2)),3).
#  :- observe(object(cell,(2,3)),value(collision,()),4), observe(object(robot,charger),value(at,(3,3)),3), occurs(object(robot,charger),action(move,(2,3)),3).
#  :- observe(object(cell,(2,3)),value(collision,()),4), observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(2,3)),3).
#  :- observe(object(cell,(2,3)),value(collision,()),4), observe(object(robot,worker),value(at,(3,3)),3), occurs(object(robot,worker),action(move,(2,3)),3).
#  :- observe(object(cell,(2,3)),value(collision,()),4), observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(2,3)),3).
#  :- observe(object(cell,(3,2)),value(collision,()),4), observe(object(robot,charger),value(at,(3,3)),3), occurs(object(robot,charger),action(move,(3,2)),3).
#  :- observe(object(cell,(3,2)),value(collision,()),4), observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(3,2)),3).
#  :- observe(object(cell,(3,2)),value(collision,()),4), observe(object(robot,worker),value(at,(3,3)),3), occurs(object(robot,worker),action(move,(3,2)),3).
#  :- observe(object(cell,(3,2)),value(collision,()),4), observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(3,2)),3).
#  :- observe(object(cell,(3,3)),value(collision,()),4), observe(object(robot,charger),value(at,(3,2)),3), occurs(object(robot,charger),action(move,(3,3)),3).
#  :- observe(object(cell,(3,3)),value(collision,()),4), observe(object(robot,charger),value(at,(2,3)),3), occurs(object(robot,charger),action(move,(3,3)),3).
#  :- observe(object(cell,(3,3)),value(collision,()),4), observe(object(robot,worker),value(at,(3,2)),3), occurs(object(robot,worker),action(move,(3,3)),3).
#  :- observe(object(cell,(3,3)),value(collision,()),4), observe(object(robot,worker),value(at,(2,3)),3), occurs(object(robot,worker),action(move,(3,3)),3).
# __x1.
# __x2.
# __x3.
# __x4.
# __x5.
# __x6.
# __x7.
# __x8.
# __x9.
# __x10.
# __x11.
# __x12.
# __x13.
# __x14.
# __x15.
# __x16.
# __x17.
# __x18.
# __x19.
# __x20.
# __x21.
# __x22.
# __x23.
# __x24.
# __x25.
# __x26.
# __x27.
# __x28.
# __x29.
# __x30.
# __x31.
# __x32.
# __x33.
# __x34.
# __x35.
# __x36.
# __x37.
# __x38.
# __x39.
# __x40.
# __x41.
# __x42.
# __x43.
# __x44.
# __x45.
# __x46.
# __x47.
# __x48.
# __x49.
# __x50.
# __x51.
# __x52.
# __x53.
# __x54.
# __x55.
# __x56.
# __x57.
# __x58.
# __x59.
# observe(object(robot,charger),value(at,(3,3)),1) :- observe(object(robot,charger),value(at,(3,3)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(3,3)),1) :- observe(object(robot,charger),value(at,(3,2)),0), occurs(object(robot,charger),action(move,(3,3)),0).
# observe(object(robot,charger),value(at,(3,3)),1) :- observe(object(robot,charger),value(at,(2,3)),0), occurs(object(robot,charger),action(move,(3,3)),0).
# observe(object(robot,charger),value(at,(3,2)),1) :- observe(object(robot,charger),value(at,(3,3)),0), occurs(object(robot,charger),action(move,(3,2)),0).
# observe(object(robot,charger),value(at,(3,2)),1) :- observe(object(robot,charger),value(at,(3,2)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(3,2)),1) :- observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(3,2)),0).
# observe(object(robot,charger),value(at,(2,3)),1) :- observe(object(robot,charger),value(at,(3,3)),0), occurs(object(robot,charger),action(move,(2,3)),0).
# observe(object(robot,charger),value(at,(2,3)),1) :- observe(object(robot,charger),value(at,(2,3)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(2,3)),1) :- observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(2,3)),0).
# observe(object(robot,charger),value(at,(2,2)),1) :- observe(object(robot,charger),value(at,(3,2)),0), occurs(object(robot,charger),action(move,(2,2)),0).
# observe(object(robot,charger),value(at,(2,2)),1) :- observe(object(robot,charger),value(at,(2,3)),0), occurs(object(robot,charger),action(move,(2,2)),0).
# observe(object(robot,charger),value(at,(2,2)),1) :- observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(2,2)),1) :- observe(object(robot,charger),value(at,(2,1)),0), occurs(object(robot,charger),action(move,(2,2)),0).
# observe(object(robot,charger),value(at,(2,2)),1) :- observe(object(robot,charger),value(at,(1,2)),0), occurs(object(robot,charger),action(move,(2,2)),0).
# observe(object(robot,charger),value(at,(2,1)),1) :- observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(2,1)),0).
# observe(object(robot,charger),value(at,(2,1)),1) :- observe(object(robot,charger),value(at,(2,1)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(2,1)),1) :- observe(object(robot,charger),value(at,(1,1)),0), occurs(object(robot,charger),action(move,(2,1)),0).
# observe(object(robot,charger),value(at,(1,2)),1) :- observe(object(robot,charger),value(at,(2,2)),0), occurs(object(robot,charger),action(move,(1,2)),0).
# observe(object(robot,charger),value(at,(1,2)),1) :- observe(object(robot,charger),value(at,(1,2)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,charger),value(at,(1,2)),1) :- observe(object(robot,charger),value(at,(1,1)),0), occurs(object(robot,charger),action(move,(1,2)),0).
# observe(object(robot,charger),value(at,(1,1)),1) :- observe(object(robot,charger),value(at,(2,1)),0), occurs(object(robot,charger),action(move,(1,1)),0).
# observe(object(robot,charger),value(at,(1,1)),1) :- observe(object(robot,charger),value(at,(1,2)),0), occurs(object(robot,charger),action(move,(1,1)),0).
# observe(object(robot,charger),value(at,(1,1)),1) :- observe(object(robot,charger),value(at,(1,1)),0), occurs(object(robot,charger),action(wait,()),0).
# observe(object(robot,worker),value(at,(3,3)),1) :- observe(object(robot,worker),value(at,(3,3)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(3,3)),1) :- observe(object(robot,worker),value(at,(3,2)),0), occurs(object(robot,worker),action(move,(3,3)),0).
# observe(object(robot,worker),value(at,(3,3)),1) :- observe(object(robot,worker),value(at,(2,3)),0), occurs(object(robot,worker),action(move,(3,3)),0).
# observe(object(robot,worker),value(at,(3,2)),1) :- observe(object(robot,worker),value(at,(3,3)),0), occurs(object(robot,worker),action(move,(3,2)),0).
# observe(object(robot,worker),value(at,(3,2)),1) :- observe(object(robot,worker),value(at,(3,2)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(3,2)),1) :- observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(3,2)),0).
# observe(object(robot,worker),value(at,(2,3)),1) :- observe(object(robot,worker),value(at,(3,3)),0), occurs(object(robot,worker),action(move,(2,3)),0).
# observe(object(robot,worker),value(at,(2,3)),1) :- observe(object(robot,worker),value(at,(2,3)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(2,3)),1) :- observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(2,3)),0).
# observe(object(robot,worker),value(at,(2,2)),1) :- observe(object(robot,worker),value(at,(3,2)),0), occurs(object(robot,worker),action(move,(2,2)),0).
# observe(object(robot,worker),value(at,(2,2)),1) :- observe(object(robot,worker),value(at,(2,3)),0), occurs(object(robot,worker),action(move,(2,2)),0).
# observe(object(robot,worker),value(at,(2,2)),1) :- observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(2,2)),1) :- observe(object(robot,worker),value(at,(2,1)),0), occurs(object(robot,worker),action(move,(2,2)),0).
# observe(object(robot,worker),value(at,(2,2)),1) :- observe(object(robot,worker),value(at,(1,2)),0), occurs(object(robot,worker),action(move,(2,2)),0).
# observe(object(robot,worker),value(at,(2,1)),1) :- observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(2,1)),0).
# observe(object(robot,worker),value(at,(2,1)),1) :- observe(object(robot,worker),value(at,(2,1)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(2,1)),1) :- observe(object(robot,worker),value(at,(1,1)),0), occurs(object(robot,worker),action(move,(2,1)),0).
# observe(object(robot,worker),value(at,(1,2)),1) :- observe(object(robot,worker),value(at,(2,2)),0), occurs(object(robot,worker),action(move,(1,2)),0).
# observe(object(robot,worker),value(at,(1,2)),1) :- observe(object(robot,worker),value(at,(1,2)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(1,2)),1) :- observe(object(robot,worker),value(at,(1,1)),0), occurs(object(robot,worker),action(move,(1,2)),0).
# observe(object(robot,worker),value(at,(1,1)),1) :- observe(object(robot,worker),value(at,(2,1)),0), occurs(object(robot,worker),action(move,(1,1)),0).
# observe(object(robot,worker),value(at,(1,1)),1) :- observe(object(robot,worker),value(at,(1,2)),0), occurs(object(robot,worker),action(move,(1,1)),0).
# observe(object(robot,worker),value(at,(1,1)),1) :- observe(object(robot,worker),value(at,(1,1)),0), occurs(object(robot,worker),action(wait,()),0).
# observe(object(robot,worker),value(at,(1,1)),2) :- observe(object(robot,worker),value(at,(2,1)),1), occurs(object(robot,worker),action(move,(1,1)),1).
# observe(object(robot,worker),value(at,(1,1)),2) :- observe(object(robot,worker),value(at,(1,2)),1), occurs(object(robot,worker),action(move,(1,1)),1).
# observe(object(robot,worker),value(at,(1,1)),2) :- observe(object(robot,worker),value(at,(1,1)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(1,2)),2) :- observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(1,2)),1).
# observe(object(robot,worker),value(at,(1,2)),2) :- observe(object(robot,worker),value(at,(1,2)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(1,2)),2) :- observe(object(robot,worker),value(at,(1,1)),1), occurs(object(robot,worker),action(move,(1,2)),1).
# observe(object(robot,worker),value(at,(2,1)),2) :- observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(2,1)),1).
# observe(object(robot,worker),value(at,(2,1)),2) :- observe(object(robot,worker),value(at,(2,1)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(2,1)),2) :- observe(object(robot,worker),value(at,(1,1)),1), occurs(object(robot,worker),action(move,(2,1)),1).
# observe(object(robot,worker),value(at,(2,2)),2) :- observe(object(robot,worker),value(at,(3,2)),1), occurs(object(robot,worker),action(move,(2,2)),1).
# observe(object(robot,worker),value(at,(2,2)),2) :- observe(object(robot,worker),value(at,(2,3)),1), occurs(object(robot,worker),action(move,(2,2)),1).
# observe(object(robot,worker),value(at,(2,2)),2) :- observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(2,2)),2) :- observe(object(robot,worker),value(at,(2,1)),1), occurs(object(robot,worker),action(move,(2,2)),1).
# observe(object(robot,worker),value(at,(2,2)),2) :- observe(object(robot,worker),value(at,(1,2)),1), occurs(object(robot,worker),action(move,(2,2)),1).
# observe(object(robot,worker),value(at,(2,3)),2) :- observe(object(robot,worker),value(at,(3,3)),1), occurs(object(robot,worker),action(move,(2,3)),1).
# observe(object(robot,worker),value(at,(2,3)),2) :- observe(object(robot,worker),value(at,(2,3)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(2,3)),2) :- observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(2,3)),1).
# observe(object(robot,worker),value(at,(3,2)),2) :- observe(object(robot,worker),value(at,(3,3)),1), occurs(object(robot,worker),action(move,(3,2)),1).
# observe(object(robot,worker),value(at,(3,2)),2) :- observe(object(robot,worker),value(at,(3,2)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(3,2)),2) :- observe(object(robot,worker),value(at,(2,2)),1), occurs(object(robot,worker),action(move,(3,2)),1).
# observe(object(robot,worker),value(at,(3,3)),2) :- observe(object(robot,worker),value(at,(3,3)),1), occurs(object(robot,worker),action(wait,()),1).
# observe(object(robot,worker),value(at,(3,3)),2) :- observe(object(robot,worker),value(at,(3,2)),1), occurs(object(robot,worker),action(move,(3,3)),1).
# observe(object(robot,worker),value(at,(3,3)),2) :- observe(object(robot,worker),value(at,(2,3)),1), occurs(object(robot,worker),action(move,(3,3)),1).
# observe(object(robot,charger),value(at,(1,1)),2) :- observe(object(robot,charger),value(at,(2,1)),1), occurs(object(robot,charger),action(move,(1,1)),1).
# observe(object(robot,charger),value(at,(1,1)),2) :- observe(object(robot,charger),value(at,(1,2)),1), occurs(object(robot,charger),action(move,(1,1)),1).
# observe(object(robot,charger),value(at,(1,1)),2) :- observe(object(robot,charger),value(at,(1,1)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(1,2)),2) :- observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(1,2)),1).
# observe(object(robot,charger),value(at,(1,2)),2) :- observe(object(robot,charger),value(at,(1,2)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(1,2)),2) :- observe(object(robot,charger),value(at,(1,1)),1), occurs(object(robot,charger),action(move,(1,2)),1).
# observe(object(robot,charger),value(at,(2,1)),2) :- observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(2,1)),1).
# observe(object(robot,charger),value(at,(2,1)),2) :- observe(object(robot,charger),value(at,(2,1)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(2,1)),2) :- observe(object(robot,charger),value(at,(1,1)),1), occurs(object(robot,charger),action(move,(2,1)),1).
# observe(object(robot,charger),value(at,(2,2)),2) :- observe(object(robot,charger),value(at,(3,2)),1), occurs(object(robot,charger),action(move,(2,2)),1).
# observe(object(robot,charger),value(at,(2,2)),2) :- observe(object(robot,charger),value(at,(2,3)),1), occurs(object(robot,charger),action(move,(2,2)),1).
# observe(object(robot,charger),value(at,(2,2)),2) :- observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(2,2)),2) :- observe(object(robot,charger),value(at,(2,1)),1), occurs(object(robot,charger),action(move,(2,2)),1).
# observe(object(robot,charger),value(at,(2,2)),2) :- observe(object(robot,charger),value(at,(1,2)),1), occurs(object(robot,charger),action(move,(2,2)),1).
# observe(object(robot,charger),value(at,(2,3)),2) :- observe(object(robot,charger),value(at,(3,3)),1), occurs(object(robot,charger),action(move,(2,3)),1).
# observe(object(robot,charger),value(at,(2,3)),2) :- observe(object(robot,charger),value(at,(2,3)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(2,3)),2) :- observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(2,3)),1).
# observe(object(robot,charger),value(at,(3,2)),2) :- observe(object(robot,charger),value(at,(3,3)),1), occurs(object(robot,charger),action(move,(3,2)),1).
# observe(object(robot,charger),value(at,(3,2)),2) :- observe(object(robot,charger),value(at,(3,2)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(3,2)),2) :- observe(object(robot,charger),value(at,(2,2)),1), occurs(object(robot,charger),action(move,(3,2)),1).
# observe(object(robot,charger),value(at,(3,3)),2) :- observe(object(robot,charger),value(at,(3,3)),1), occurs(object(robot,charger),action(wait,()),1).
# observe(object(robot,charger),value(at,(3,3)),2) :- observe(object(robot,charger),value(at,(3,2)),1), occurs(object(robot,charger),action(move,(3,3)),1).
# observe(object(robot,charger),value(at,(3,3)),2) :- observe(object(robot,charger),value(at,(2,3)),1), occurs(object(robot,charger),action(move,(3,3)),1).
# observe(object(robot,charger),value(at,(3,3)),3) :- observe(object(robot,charger),value(at,(2,3)),2), occurs(object(robot,charger),action(move,(3,3)),2).
# observe(object(robot,charger),value(at,(3,3)),3) :- observe(object(robot,charger),value(at,(3,2)),2), occurs(object(robot,charger),action(move,(3,3)),2).
# observe(object(robot,charger),value(at,(3,3)),3) :- observe(object(robot,charger),value(at,(3,3)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(3,2)),3) :- observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(3,2)),2).
# observe(object(robot,charger),value(at,(3,2)),3) :- observe(object(robot,charger),value(at,(3,2)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(3,2)),3) :- observe(object(robot,charger),value(at,(3,3)),2), occurs(object(robot,charger),action(move,(3,2)),2).
# observe(object(robot,charger),value(at,(2,3)),3) :- observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(2,3)),2).
# observe(object(robot,charger),value(at,(2,3)),3) :- observe(object(robot,charger),value(at,(2,3)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(2,3)),3) :- observe(object(robot,charger),value(at,(3,3)),2), occurs(object(robot,charger),action(move,(2,3)),2).
# observe(object(robot,charger),value(at,(2,2)),3) :- observe(object(robot,charger),value(at,(1,2)),2), occurs(object(robot,charger),action(move,(2,2)),2).
# observe(object(robot,charger),value(at,(2,2)),3) :- observe(object(robot,charger),value(at,(2,1)),2), occurs(object(robot,charger),action(move,(2,2)),2).
# observe(object(robot,charger),value(at,(2,2)),3) :- observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(2,2)),3) :- observe(object(robot,charger),value(at,(2,3)),2), occurs(object(robot,charger),action(move,(2,2)),2).
# observe(object(robot,charger),value(at,(2,2)),3) :- observe(object(robot,charger),value(at,(3,2)),2), occurs(object(robot,charger),action(move,(2,2)),2).
# observe(object(robot,charger),value(at,(2,1)),3) :- observe(object(robot,charger),value(at,(1,1)),2), occurs(object(robot,charger),action(move,(2,1)),2).
# observe(object(robot,charger),value(at,(2,1)),3) :- observe(object(robot,charger),value(at,(2,1)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(2,1)),3) :- observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(2,1)),2).
# observe(object(robot,charger),value(at,(1,2)),3) :- observe(object(robot,charger),value(at,(1,1)),2), occurs(object(robot,charger),action(move,(1,2)),2).
# observe(object(robot,charger),value(at,(1,2)),3) :- observe(object(robot,charger),value(at,(1,2)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(1,2)),3) :- observe(object(robot,charger),value(at,(2,2)),2), occurs(object(robot,charger),action(move,(1,2)),2).
# observe(object(robot,charger),value(at,(1,1)),3) :- observe(object(robot,charger),value(at,(1,1)),2), occurs(object(robot,charger),action(wait,()),2).
# observe(object(robot,charger),value(at,(1,1)),3) :- observe(object(robot,charger),value(at,(1,2)),2), occurs(object(robot,charger),action(move,(1,1)),2).
# observe(object(robot,charger),value(at,(1,1)),3) :- observe(object(robot,charger),value(at,(2,1)),2), occurs(object(robot,charger),action(move,(1,1)),2).
# observe(object(robot,worker),value(at,(3,3)),3) :- observe(object(robot,worker),value(at,(2,3)),2), occurs(object(robot,worker),action(move,(3,3)),2).
# observe(object(robot,worker),value(at,(3,3)),3) :- observe(object(robot,worker),value(at,(3,2)),2), occurs(object(robot,worker),action(move,(3,3)),2).
# observe(object(robot,worker),value(at,(3,3)),3) :- observe(object(robot,worker),value(at,(3,3)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(3,2)),3) :- observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(3,2)),2).
# observe(object(robot,worker),value(at,(3,2)),3) :- observe(object(robot,worker),value(at,(3,2)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(3,2)),3) :- observe(object(robot,worker),value(at,(3,3)),2), occurs(object(robot,worker),action(move,(3,2)),2).
# observe(object(robot,worker),value(at,(2,3)),3) :- observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(2,3)),2).
# observe(object(robot,worker),value(at,(2,3)),3) :- observe(object(robot,worker),value(at,(2,3)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(2,3)),3) :- observe(object(robot,worker),value(at,(3,3)),2), occurs(object(robot,worker),action(move,(2,3)),2).
# observe(object(robot,worker),value(at,(2,2)),3) :- observe(object(robot,worker),value(at,(1,2)),2), occurs(object(robot,worker),action(move,(2,2)),2).
# observe(object(robot,worker),value(at,(2,2)),3) :- observe(object(robot,worker),value(at,(2,1)),2), occurs(object(robot,worker),action(move,(2,2)),2).
# observe(object(robot,worker),value(at,(2,2)),3) :- observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(2,2)),3) :- observe(object(robot,worker),value(at,(2,3)),2), occurs(object(robot,worker),action(move,(2,2)),2).
# observe(object(robot,worker),value(at,(2,2)),3) :- observe(object(robot,worker),value(at,(3,2)),2), occurs(object(robot,worker),action(move,(2,2)),2).
# observe(object(robot,worker),value(at,(2,1)),3) :- observe(object(robot,worker),value(at,(1,1)),2), occurs(object(robot,worker),action(move,(2,1)),2).
# observe(object(robot,worker),value(at,(2,1)),3) :- observe(object(robot,worker),value(at,(2,1)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(2,1)),3) :- observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(2,1)),2).
# observe(object(robot,worker),value(at,(1,2)),3) :- observe(object(robot,worker),value(at,(1,1)),2), occurs(object(robot,worker),action(move,(1,2)),2).
# observe(object(robot,worker),value(at,(1,2)),3) :- observe(object(robot,worker),value(at,(1,2)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(1,2)),3) :- observe(object(robot,worker),value(at,(2,2)),2), occurs(object(robot,worker),action(move,(1,2)),2).
# observe(object(robot,worker),value(at,(1,1)),3) :- observe(object(robot,worker),value(at,(1,1)),2), occurs(object(robot,worker),action(wait,()),2).
# observe(object(robot,worker),value(at,(1,1)),3) :- observe(object(robot,worker),value(at,(1,2)),2), occurs(object(robot,worker),action(move,(1,1)),2).
# observe(object(robot,worker),value(at,(1,1)),3) :- observe(object(robot,worker),value(at,(2,1)),2), occurs(object(robot,worker),action(move,(1,1)),2).
# observe(object(robot,worker),value(at,(1,1)),4) :- observe(object(robot,worker),value(at,(2,1)),3), occurs(object(robot,worker),action(move,(1,1)),3).
# observe(object(robot,worker),value(at,(1,1)),4) :- observe(object(robot,worker),value(at,(1,2)),3), occurs(object(robot,worker),action(move,(1,1)),3).
# observe(object(robot,worker),value(at,(1,1)),4) :- observe(object(robot,worker),value(at,(1,1)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(1,2)),4) :- observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(1,2)),3).
# observe(object(robot,worker),value(at,(1,2)),4) :- observe(object(robot,worker),value(at,(1,2)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(1,2)),4) :- observe(object(robot,worker),value(at,(1,1)),3), occurs(object(robot,worker),action(move,(1,2)),3).
# observe(object(robot,worker),value(at,(2,1)),4) :- observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(2,1)),3).
# observe(object(robot,worker),value(at,(2,1)),4) :- observe(object(robot,worker),value(at,(2,1)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(2,1)),4) :- observe(object(robot,worker),value(at,(1,1)),3), occurs(object(robot,worker),action(move,(2,1)),3).
# observe(object(robot,worker),value(at,(2,2)),4) :- observe(object(robot,worker),value(at,(3,2)),3), occurs(object(robot,worker),action(move,(2,2)),3).
# observe(object(robot,worker),value(at,(2,2)),4) :- observe(object(robot,worker),value(at,(2,3)),3), occurs(object(robot,worker),action(move,(2,2)),3).
# observe(object(robot,worker),value(at,(2,2)),4) :- observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(2,2)),4) :- observe(object(robot,worker),value(at,(2,1)),3), occurs(object(robot,worker),action(move,(2,2)),3).
# observe(object(robot,worker),value(at,(2,2)),4) :- observe(object(robot,worker),value(at,(1,2)),3), occurs(object(robot,worker),action(move,(2,2)),3).
# observe(object(robot,worker),value(at,(2,3)),4) :- observe(object(robot,worker),value(at,(3,3)),3), occurs(object(robot,worker),action(move,(2,3)),3).
# observe(object(robot,worker),value(at,(2,3)),4) :- observe(object(robot,worker),value(at,(2,3)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(2,3)),4) :- observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(2,3)),3).
# observe(object(robot,worker),value(at,(3,2)),4) :- observe(object(robot,worker),value(at,(3,3)),3), occurs(object(robot,worker),action(move,(3,2)),3).
# observe(object(robot,worker),value(at,(3,2)),4) :- observe(object(robot,worker),value(at,(3,2)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(3,2)),4) :- observe(object(robot,worker),value(at,(2,2)),3), occurs(object(robot,worker),action(move,(3,2)),3).
# observe(object(robot,worker),value(at,(3,3)),4) :- observe(object(robot,worker),value(at,(3,3)),3), occurs(object(robot,worker),action(wait,()),3).
# observe(object(robot,worker),value(at,(3,3)),4) :- observe(object(robot,worker),value(at,(3,2)),3), occurs(object(robot,worker),action(move,(3,3)),3).
# observe(object(robot,worker),value(at,(3,3)),4) :- observe(object(robot,worker),value(at,(2,3)),3), occurs(object(robot,worker),action(move,(3,3)),3).
# observe(object(robot,charger),value(at,(1,1)),4) :- observe(object(robot,charger),value(at,(2,1)),3), occurs(object(robot,charger),action(move,(1,1)),3).
# observe(object(robot,charger),value(at,(1,1)),4) :- observe(object(robot,charger),value(at,(1,2)),3), occurs(object(robot,charger),action(move,(1,1)),3).
# observe(object(robot,charger),value(at,(1,1)),4) :- observe(object(robot,charger),value(at,(1,1)),3), occurs(object(robot,charger),action(wait,()),3).
# observe(object(robot,charger),value(at,(1,2)),4) :- observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(1,2)),3).
# observe(object(robot,charger),value(at,(1,2)),4) :- observe(object(robot,charger),value(at,(1,2)),3), occurs(object(robot,charger),action(wait,()),3).
# observe(object(robot,charger),value(at,(1,2)),4) :- observe(object(robot,charger),value(at,(1,1)),3), occurs(object(robot,charger),action(move,(1,2)),3).
# observe(object(robot,charger),value(at,(2,1)),4) :- observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(2,1)),3).
# observe(object(robot,charger),value(at,(2,1)),4) :- observe(object(robot,charger),value(at,(2,1)),3), occurs(object(robot,charger),action(wait,()),3).
# observe(object(robot,charger),value(at,(2,1)),4) :- observe(object(robot,charger),value(at,(1,1)),3), occurs(object(robot,charger),action(move,(2,1)),3).
# observe(object(robot,charger),value(at,(2,2)),4) :- observe(object(robot,charger),value(at,(3,2)),3), occurs(object(robot,charger),action(move,(2,2)),3).
# observe(object(robot,charger),value(at,(2,2)),4) :- observe(object(robot,charger),value(at,(2,3)),3), occurs(object(robot,charger),action(move,(2,2)),3).
# observe(object(robot,charger),value(at,(2,2)),4) :- observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(wait,()),3).
# observe(object(robot,charger),value(at,(2,2)),4) :- observe(object(robot,charger),value(at,(2,1)),3), occurs(object(robot,charger),action(move,(2,2)),3).
# observe(object(robot,charger),value(at,(2,2)),4) :- observe(object(robot,charger),value(at,(1,2)),3), occurs(object(robot,charger),action(move,(2,2)),3).
# observe(object(robot,charger),value(at,(2,3)),4) :- observe(object(robot,charger),value(at,(3,3)),3), occurs(object(robot,charger),action(move,(2,3)),3).
# observe(object(robot,charger),value(at,(2,3)),4) :- observe(object(robot,charger),value(at,(2,3)),3), occurs(object(robot,charger),action(wait,()),3).
# observe(object(robot,charger),value(at,(2,3)),4) :- observe(object(robot,charger),value(at,(2,2)),3), occurs(object(robot,charger),action(move,(2,3)),3).
# observe(object(robot,charger),value(at,(3,2)),4) :- observe(object(robot,charger),value(at,(3,3)),3), occurs(object(robot,charger),action(move,(3,2)),3).
# ...
# observe(object(cell,(2,1)),value(collision,()),4) :- occurs(object(robot,charger),action(move,(2,1)),3), observe(object(robot,worker),value(at,(2,1)),3).
# observe(object(cell,(2,2)),value(collision,()),4) :- observe(object(robot,worker),value(at,(2,2)),4), observe(object(robot,charger),value(at,(2,2)),4).
# observe(object(cell,(2,2)),value(collision,()),4) :- observe(object(robot,charger),value(at,(2,2)),4), observe(object(robot,worker),value(at,(2,2)),4).
# observe(object(cell,(2,2)),value(collision,()),4) :- occurs(object(robot,worker),action(move,(2,2)),3), observe(object(robot,charger),value(at,(2,2)),3).
# observe(object(cell,(2,2)),value(collision,()),4) :- occurs(object(robot,charger),action(move,(2,2)),3), observe(object(robot,worker),value(at,(2,2)),3).
# observe(object(cell,(2,3)),value(collision,()),4) :- observe(object(robot,worker),value(at,(2,3)),4), observe(object(robot,charger),value(at,(2,3)),4).
# observe(object(cell,(2,3)),value(collision,()),4) :- observe(object(robot,charger),value(at,(2,3)),4), observe(object(robot,worker),value(at,(2,3)),4).
# observe(object(cell,(2,3)),value(collision,()),4) :- occurs(object(robot,worker),action(move,(2,3)),3), observe(object(robot,charger),value(at,(2,3)),3).
# observe(object(cell,(2,3)),value(collision,()),4) :- occurs(object(robot,charger),action(move,(2,3)),3), observe(object(robot,worker),value(at,(2,3)),3).
# observe(object(cell,(3,2)),value(collision,()),4) :- observe(object(robot,worker),value(at,(3,2)),4), observe(object(robot,charger),value(at,(3,2)),4).
# observe(object(cell,(3,2)),value(collision,()),4) :- observe(object(robot,charger),value(at,(3,2)),4), observe(object(robot,worker),value(at,(3,2)),4).
# observe(object(cell,(3,2)),value(collision,()),4) :- occurs(object(robot,worker),action(move,(3,2)),3), observe(object(robot,charger),value(at,(3,2)),3).
# observe(object(cell,(3,2)),value(collision,()),4) :- occurs(object(robot,charger),action(move,(3,2)),3), observe(object(robot,worker),value(at,(3,2)),3).
# observe(object(cell,(3,3)),value(collision,()),4) :- observe(object(robot,worker),value(at,(3,3)),4), observe(object(robot,charger),value(at,(3,3)),4).
# observe(object(cell,(3,3)),value(collision,()),4) :- observe(object(robot,charger),value(at,(3,3)),4), observe(object(robot,worker),value(at,(3,3)),4).
# observe(object(cell,(3,3)),value(collision,()),4) :- occurs(object(robot,worker),action(move,(3,3)),3), observe(object(robot,charger),value(at,(3,3)),3).
# observe(object(cell,(3,3)),value(collision,()),4) :- occurs(object(robot,charger),action(move,(3,3)),3), observe(object(robot,worker),value(at,(3,3)),3).
# __x231 :- __x229, not __x230.
# __x234 :- __x232, not __x233.
# __x237 :- __x235, not __x236.
# __x240 :- __x238, not __x239.
# __x243 :- __x241, not __x242.
# __x246 :- __x244, not __x245.
# __x249 :- __x247, not __x248.
# __x252 :- __x250, not __x251.
# __x255 :- __x253, not __x254.
# __x258 :- __x256, not __x257.
# {occurs(object(robot,charger),action(wait,()),0); occurs(object(robot,charger),action(move,(1,1)),0); occurs(object(robot,charger),action(move,(1,2)),0); occurs(object(robot,charger),action(move,(2,1)),0); occurs(object(robot,charger),action(move,(2,2)),0); occurs(object(robot,charger),action(move,(2,3)),0); occurs(object(robot,charger),action(move,(3,2)),0); occurs(object(robot,charger),action(move,(3,3)),0)} :- __x17.
# {observe(object(robot,charger),value(at,(1,1)),0); observe(object(robot,charger),value(at,(1,2)),0); observe(object(robot,charger),value(at,(2,1)),0); observe(object(robot,charger),value(at,(2,2)),0); observe(object(robot,charger),value(at,(2,3)),0); observe(object(robot,charger),value(at,(3,2)),0); observe(object(robot,charger),value(at,(3,3)),0)} :- __x43.
# {occurs(object(robot,worker),action(wait,()),0); occurs(object(robot,worker),action(move,(1,1)),0); occurs(object(robot,worker),action(move,(1,2)),0); occurs(object(robot,worker),action(move,(2,1)),0); occurs(object(robot,worker),action(move,(2,2)),0); occurs(object(robot,worker),action(move,(2,3)),0); occurs(object(robot,worker),action(move,(3,2)),0); occurs(object(robot,worker),action(move,(3,3)),0)} :- __x13.
# {observe(object(robot,worker),value(at,(1,1)),0); observe(object(robot,worker),value(at,(1,2)),0); observe(object(robot,worker),value(at,(2,1)),0); observe(object(robot,worker),value(at,(2,2)),0); observe(object(robot,worker),value(at,(2,3)),0); observe(object(robot,worker),value(at,(3,2)),0); observe(object(robot,worker),value(at,(3,3)),0)} :- __x42.
# {occurs(object(robot,worker),action(wait,()),1); occurs(object(robot,worker),action(move,(1,1)),1); occurs(object(robot,worker),action(move,(1,2)),1); occurs(object(robot,worker),action(move,(2,1)),1); occurs(object(robot,worker),action(move,(2,2)),1); occurs(object(robot,worker),action(move,(2,3)),1); occurs(object(robot,worker),action(move,(3,2)),1); occurs(object(robot,worker),action(move,(3,3)),1)} :- __x14.
# {occurs(object(robot,charger),action(wait,()),1); occurs(object(robot,charger),action(move,(1,1)),1); occurs(object(robot,charger),action(move,(1,2)),1); occurs(object(robot,charger),action(move,(2,1)),1); occurs(object(robot,charger),action(move,(2,2)),1); occurs(object(robot,charger),action(move,(2,3)),1); occurs(object(robot,charger),action(move,(3,2)),1); occurs(object(robot,charger),action(move,(3,3)),1)} :- __x18.
# {occurs(object(robot,charger),action(wait,()),2); occurs(object(robot,charger),action(move,(1,1)),2); occurs(object(robot,charger),action(move,(1,2)),2); occurs(object(robot,charger),action(move,(2,1)),2); occurs(object(robot,charger),action(move,(2,2)),2); occurs(object(robot,charger),action(move,(2,3)),2); occurs(object(robot,charger),action(move,(3,2)),2); occurs(object(robot,charger),action(move,(3,3)),2)} :- __x19.
# {occurs(object(robot,worker),action(wait,()),2); occurs(object(robot,worker),action(move,(1,1)),2); occurs(object(robot,worker),action(move,(1,2)),2); occurs(object(robot,worker),action(move,(2,1)),2); occurs(object(robot,worker),action(move,(2,2)),2); occurs(object(robot,worker),action(move,(2,3)),2); occurs(object(robot,worker),action(move,(3,2)),2); occurs(object(robot,worker),action(move,(3,3)),2)} :- __x15.
# {occurs(object(robot,worker),action(wait,()),3); occurs(object(robot,worker),action(move,(1,1)),3); occurs(object(robot,worker),action(move,(1,2)),3); occurs(object(robot,worker),action(move,(2,1)),3); occurs(object(robot,worker),action(move,(2,2)),3); occurs(object(robot,worker),action(move,(2,3)),3); occurs(object(robot,worker),action(move,(3,2)),3); occurs(object(robot,worker),action(move,(3,3)),3)} :- __x16.
# {occurs(object(robot,charger),action(wait,()),3); occurs(object(robot,charger),action(move,(1,1)),3); occurs(object(robot,charger),action(move,(1,2)),3); occurs(object(robot,charger),action(move,(2,1)),3); occurs(object(robot,charger),action(move,(2,2)),3); occurs(object(robot,charger),action(move,(2,3)),3); occurs(object(robot,charger),action(move,(3,2)),3); occurs(object(robot,charger),action(move,(3,3)),3)} :- __x20.
# __x229 :- 1{1,0: occurs(object(robot,worker),action(wait,()),0), 1,1: occurs(object(robot,worker),action(move,(1,1)),0), 1,2: occurs(object(robot,worker),action(move,(1,2)),0), 1,3: occurs(object(robot,worker),action(move,(2,1)),0), 1,4: occurs(object(robot,worker),action(move,(2,2)),0), 1,5: occurs(object(robot,worker),action(move,(2,3)),0), 1,6: occurs(object(robot,worker),action(move,(3,2)),0), 1,7: occurs(object(robot,worker),action(move,(3,3)),0)}.
# __x230 :- 2{1,0: occurs(object(robot,worker),action(wait,()),0), 1,1: occurs(object(robot,worker),action(move,(1,1)),0), 1,2: occurs(object(robot,worker),action(move,(1,2)),0), 1,3: occurs(object(robot,worker),action(move,(2,1)),0), 1,4: occurs(object(robot,worker),action(move,(2,2)),0), 1,5: occurs(object(robot,worker),action(move,(2,3)),0), 1,6: occurs(object(robot,worker),action(move,(3,2)),0), 1,7: occurs(object(robot,worker),action(move,(3,3)),0)}.
# __x232 :- 1{1,0: occurs(object(robot,worker),action(wait,()),1), 1,1: occurs(object(robot,worker),action(move,(1,1)),1), 1,2: occurs(object(robot,worker),action(move,(1,2)),1), 1,3: occurs(object(robot,worker),action(move,(2,1)),1), 1,4: occurs(object(robot,worker),action(move,(2,2)),1), 1,5: occurs(object(robot,worker),action(move,(2,3)),1), 1,6: occurs(object(robot,worker),action(move,(3,2)),1), 1,7: occurs(object(robot,worker),action(move,(3,3)),1)}.
# __x233 :- 2{1,0: occurs(object(robot,worker),action(wait,()),1), 1,1: occurs(object(robot,worker),action(move,(1,1)),1), 1,2: occurs(object(robot,worker),action(move,(1,2)),1), 1,3: occurs(object(robot,worker),action(move,(2,1)),1), 1,4: occurs(object(robot,worker),action(move,(2,2)),1), 1,5: occurs(object(robot,worker),action(move,(2,3)),1), 1,6: occurs(object(robot,worker),action(move,(3,2)),1), 1,7: occurs(object(robot,worker),action(move,(3,3)),1)}.
# __x235 :- 1{1,0: occurs(object(robot,worker),action(wait,()),2), 1,1: occurs(object(robot,worker),action(move,(1,1)),2), 1,2: occurs(object(robot,worker),action(move,(1,2)),2), 1,3: occurs(object(robot,worker),action(move,(2,1)),2), 1,4: occurs(object(robot,worker),action(move,(2,2)),2), 1,5: occurs(object(robot,worker),action(move,(2,3)),2), 1,6: occurs(object(robot,worker),action(move,(3,2)),2), 1,7: occurs(object(robot,worker),action(move,(3,3)),2)}.
# __x236 :- 2{1,0: occurs(object(robot,worker),action(wait,()),2), 1,1: occurs(object(robot,worker),action(move,(1,1)),2), 1,2: occurs(object(robot,worker),action(move,(1,2)),2), 1,3: occurs(object(robot,worker),action(move,(2,1)),2), 1,4: occurs(object(robot,worker),action(move,(2,2)),2), 1,5: occurs(object(robot,worker),action(move,(2,3)),2), 1,6: occurs(object(robot,worker),action(move,(3,2)),2), 1,7: occurs(object(robot,worker),action(move,(3,3)),2)}.
# __x238 :- 1{1,0: occurs(object(robot,worker),action(wait,()),3), 1,1: occurs(object(robot,worker),action(move,(1,1)),3), 1,2: occurs(object(robot,worker),action(move,(1,2)),3), 1,3: occurs(object(robot,worker),action(move,(2,1)),3), 1,4: occurs(object(robot,worker),action(move,(2,2)),3), 1,5: occurs(object(robot,worker),action(move,(2,3)),3), 1,6: occurs(object(robot,worker),action(move,(3,2)),3), 1,7: occurs(object(robot,worker),action(move,(3,3)),3)}.
# __x239 :- 2{1,0: occurs(object(robot,worker),action(wait,()),3), 1,1: occurs(object(robot,worker),action(move,(1,1)),3), 1,2: occurs(object(robot,worker),action(move,(1,2)),3), 1,3: occurs(object(robot,worker),action(move,(2,1)),3), 1,4: occurs(object(robot,worker),action(move,(2,2)),3), 1,5: occurs(object(robot,worker),action(move,(2,3)),3), 1,6: occurs(object(robot,worker),action(move,(3,2)),3), 1,7: occurs(object(robot,worker),action(move,(3,3)),3)}.
# __x241 :- 1{1,0: occurs(object(robot,charger),action(wait,()),0), 1,1: occurs(object(robot,charger),action(move,(1,1)),0), 1,2: occurs(object(robot,charger),action(move,(1,2)),0), 1,3: occurs(object(robot,charger),action(move,(2,1)),0), 1,4: occurs(object(robot,charger),action(move,(2,2)),0), 1,5: occurs(object(robot,charger),action(move,(2,3)),0), 1,6: occurs(object(robot,charger),action(move,(3,2)),0), 1,7: occurs(object(robot,charger),action(move,(3,3)),0)}.
# __x242 :- 2{1,0: occurs(object(robot,charger),action(wait,()),0), 1,1: occurs(object(robot,charger),action(move,(1,1)),0), 1,2: occurs(object(robot,charger),action(move,(1,2)),0), 1,3: occurs(object(robot,charger),action(move,(2,1)),0), 1,4: occurs(object(robot,charger),action(move,(2,2)),0), 1,5: occurs(object(robot,charger),action(move,(2,3)),0), 1,6: occurs(object(robot,charger),action(move,(3,2)),0), 1,7: occurs(object(robot,charger),action(move,(3,3)),0)}.
# __x244 :- 1{1,0: occurs(object(robot,charger),action(wait,()),1), 1,1: occurs(object(robot,charger),action(move,(1,1)),1), 1,2: occurs(object(robot,charger),action(move,(1,2)),1), 1,3: occurs(object(robot,charger),action(move,(2,1)),1), 1,4: occurs(object(robot,charger),action(move,(2,2)),1), 1,5: occurs(object(robot,charger),action(move,(2,3)),1), 1,6: occurs(object(robot,charger),action(move,(3,2)),1), 1,7: occurs(object(robot,charger),action(move,(3,3)),1)}.
# __x245 :- 2{1,0: occurs(object(robot,charger),action(wait,()),1), 1,1: occurs(object(robot,charger),action(move,(1,1)),1), 1,2: occurs(object(robot,charger),action(move,(1,2)),1), 1,3: occurs(object(robot,charger),action(move,(2,1)),1), 1,4: occurs(object(robot,charger),action(move,(2,2)),1), 1,5: occurs(object(robot,charger),action(move,(2,3)),1), 1,6: occurs(object(robot,charger),action(move,(3,2)),1), 1,7: occurs(object(robot,charger),action(move,(3,3)),1)}.
# __x247 :- 1{1,0: occurs(object(robot,charger),action(wait,()),2), 1,1: occurs(object(robot,charger),action(move,(1,1)),2), 1,2: occurs(object(robot,charger),action(move,(1,2)),2), 1,3: occurs(object(robot,charger),action(move,(2,1)),2), 1,4: occurs(object(robot,charger),action(move,(2,2)),2), 1,5: occurs(object(robot,charger),action(move,(2,3)),2), 1,6: occurs(object(robot,charger),action(move,(3,2)),2), 1,7: occurs(object(robot,charger),action(move,(3,3)),2)}.
# __x248 :- 2{1,0: occurs(object(robot,charger),action(wait,()),2), 1,1: occurs(object(robot,charger),action(move,(1,1)),2), 1,2: occurs(object(robot,charger),action(move,(1,2)),2), 1,3: occurs(object(robot,charger),action(move,(2,1)),2), 1,4: occurs(object(robot,charger),action(move,(2,2)),2), 1,5: occurs(object(robot,charger),action(move,(2,3)),2), 1,6: occurs(object(robot,charger),action(move,(3,2)),2), 1,7: occurs(object(robot,charger),action(move,(3,3)),2)}.
# __x250 :- 1{1,0: occurs(object(robot,charger),action(wait,()),3), 1,1: occurs(object(robot,charger),action(move,(1,1)),3), 1,2: occurs(object(robot,charger),action(move,(1,2)),3), 1,3: occurs(object(robot,charger),action(move,(2,1)),3), 1,4: occurs(object(robot,charger),action(move,(2,2)),3), 1,5: occurs(object(robot,charger),action(move,(2,3)),3), 1,6: occurs(object(robot,charger),action(move,(3,2)),3), 1,7: occurs(object(robot,charger),action(move,(3,3)),3)}.
# __x251 :- 2{1,0: occurs(object(robot,charger),action(wait,()),3), 1,1: occurs(object(robot,charger),action(move,(1,1)),3), 1,2: occurs(object(robot,charger),action(move,(1,2)),3), 1,3: occurs(object(robot,charger),action(move,(2,1)),3), 1,4: occurs(object(robot,charger),action(move,(2,2)),3), 1,5: occurs(object(robot,charger),action(move,(2,3)),3), 1,6: occurs(object(robot,charger),action(move,(3,2)),3), 1,7: occurs(object(robot,charger),action(move,(3,3)),3)}.
# __x253 :- 1{1,0: observe(object(robot,worker),value(at,(1,1)),0), 1,1: observe(object(robot,worker),value(at,(1,2)),0), 1,2: observe(object(robot,worker),value(at,(2,1)),0), 1,3: observe(object(robot,worker),value(at,(2,2)),0), 1,4: observe(object(robot,worker),value(at,(2,3)),0), 1,5: observe(object(robot,worker),value(at,(3,2)),0), 1,6: observe(object(robot,worker),value(at,(3,3)),0)}.
# __x254 :- 2{1,0: observe(object(robot,worker),value(at,(1,1)),0), 1,1: observe(object(robot,worker),value(at,(1,2)),0), 1,2: observe(object(robot,worker),value(at,(2,1)),0), 1,3: observe(object(robot,worker),value(at,(2,2)),0), 1,4: observe(object(robot,worker),value(at,(2,3)),0), 1,5: observe(object(robot,worker),value(at,(3,2)),0), 1,6: observe(object(robot,worker),value(at,(3,3)),0)}.
# __x256 :- 1{1,0: observe(object(robot,charger),value(at,(1,1)),0), 1,1: observe(object(robot,charger),value(at,(1,2)),0), 1,2: observe(object(robot,charger),value(at,(2,1)),0), 1,3: observe(object(robot,charger),value(at,(2,2)),0), 1,4: observe(object(robot,charger),value(at,(2,3)),0), 1,5: observe(object(robot,charger),value(at,(3,2)),0), 1,6: observe(object(robot,charger),value(at,(3,3)),0)}.
# __x257 :- 2{1,0: observe(object(robot,charger),value(at,(1,1)),0), 1,1: observe(object(robot,charger),value(at,(1,2)),0), 1,2: observe(object(robot,charger),value(at,(2,1)),0), 1,3: observe(object(robot,charger),value(at,(2,2)),0), 1,4: observe(object(robot,charger),value(at,(2,3)),0), 1,5: observe(object(robot,charger),value(at,(3,2)),0), 1,6: observe(object(robot,charger),value(at,(3,3)),0)}.

# %%
def get_time(symbol: clingo.Symbol, default: Union[Callable[[clingo.Symbol], int], int, None] = None):
    if symbol.type is clingo.SymbolType.Function and symbol.name in ('occurs', 'observe'):
        return symbol.arguments[-1].number
    if callable(default):
        return default(symbol)
    return default

# %%
models = []
with ctl.solve(yield_=True) as solve_handle:
    for model in solve_handle:
        symbols = sorted(sorted(model.symbols(shown=True)), key=functools.partial(get_time, default=-1))
        print("Answer {}:{}".format(model.number,'{'), '\n'.join(map(str, symbols)), '}', sep='\n')
        models.append(symbols)
    solve_result = solve_handle.get()
    print(solve_result, end='')
    if solve_result.satisfiable:
        print(' {}{}'.format(len(models), '' if solve_result.exhausted else '+'), end='')
    print()
# Out:
# Answer 1:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(1,2)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(1,2)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(wait,()),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(1,2)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(wait,()),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(1,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 2:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(1,2)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(1,2)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(move,(1,1)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(1,1)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(1,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(1,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 3:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(1,2)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(1,2)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(move,(1,1)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(1,1)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(2,1)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(2,1)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 4:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(3,2)),0)
# occurs(object(robot,worker),action(move,(1,2)),0)
# observe(object(robot,charger),value(at,(3,2)),1)
# observe(object(robot,worker),value(at,(1,2)),1)
# occurs(object(robot,charger),action(move,(3,3)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,3)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(3,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 5:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(2,3)),0)
# occurs(object(robot,worker),action(move,(1,2)),0)
# observe(object(robot,charger),value(at,(2,3)),1)
# observe(object(robot,worker),value(at,(1,2)),1)
# occurs(object(robot,charger),action(move,(3,3)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,3)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(3,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 6:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(3,2)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(3,2)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(move,(3,3)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,3)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(3,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 7:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(2,3)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(2,3)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(move,(3,3)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,3)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(3,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 8:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(3,2)),0)
# occurs(object(robot,worker),action(move,(2,1)),0)
# observe(object(robot,charger),value(at,(3,2)),1)
# observe(object(robot,worker),value(at,(2,1)),1)
# occurs(object(robot,charger),action(wait,()),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,2)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(wait,()),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 9:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(3,2)),0)
# occurs(object(robot,worker),action(move,(1,2)),0)
# observe(object(robot,charger),value(at,(3,2)),1)
# observe(object(robot,worker),value(at,(1,2)),1)
# occurs(object(robot,charger),action(wait,()),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(3,2)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(wait,()),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(3,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# Answer 10:{
# observe(object(robot,charger),value(at,(2,2)),0)
# observe(object(robot,worker),value(at,(1,1)),0)
# occurs(object(robot,charger),action(move,(2,1)),0)
# occurs(object(robot,worker),action(move,(1,2)),0)
# observe(object(robot,charger),value(at,(2,1)),1)
# observe(object(robot,worker),value(at,(1,2)),1)
# occurs(object(robot,charger),action(move,(1,1)),1)
# occurs(object(robot,worker),action(move,(2,2)),1)
# observe(object(robot,charger),value(at,(1,1)),2)
# observe(object(robot,worker),value(at,(2,2)),2)
# occurs(object(robot,charger),action(move,(1,2)),2)
# occurs(object(robot,worker),action(move,(2,3)),2)
# observe(object(robot,charger),value(at,(1,2)),3)
# observe(object(robot,worker),value(at,(2,3)),3)
# occurs(object(robot,charger),action(move,(2,2)),3)
# occurs(object(robot,worker),action(move,(3,3)),3)
# observe(object(robot,charger),value(at,(2,2)),4)
# observe(object(robot,worker),value(at,(3,3)),4)
# }
# SAT 10+
